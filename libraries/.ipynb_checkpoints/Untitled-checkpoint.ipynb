# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2CC2-60AD
#
#  Directory of C:\Users\prasath.sundararajan\libraries
#
# 13-01-2025  15:30    <DIR>          .
# 13-01-2025  15:30    <DIR>          ..
# 13-01-2025  15:31    <DIR>          .ipynb_checkpoints
# 13-01-2025  15:30             3,975 iris.csv
# 13-01-2025  14:42             2,827 numpy.ipynb
# 13-01-2025  15:27            18,752 tips.csv
# 13-01-2025  14:17               337 Untitled.ipynb
#                4 File(s)         25,891 bytes
#                3 Dir(s)  10,592,391,168 bytes free

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2CC2-60AD
#
#  Directory of C:\Users\prasath.sundararajan\libraries
#
# 13-01-2025  15:47    <DIR>          .
# 13-01-2025  15:47    <DIR>          ..
# 13-01-2025  15:31    <DIR>          .ipynb_checkpoints
# 13-01-2025  15:30             3,975 iris.csv
# 13-01-2025  14:42             2,827 numpy.ipynb
# 13-01-2025  15:27            18,752 tips.csv
# 13-01-2025  15:47            14,679 Untitled.ipynb
#                4 File(s)         40,233 bytes
#                3 Dir(s)  10,595,176,448 bytes free

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
dis=df[(df[sepal.width(cm)]>3.5)&(df['Species']=='iris-setosa')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dis=df[(df[sepal.width(cm)]>3.5)&(df['Species']=='iris-setosa')]
#
# NameError: name 'sepal' is not defined

# %%
dis=df[(df[sepal.width]>3.5)&(df['Species']=='iris-setosa')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dis=df[(df[sepal.width]>3.5)&(df['Species']=='iris-setosa')]
#
# NameError: name 'sepal' is not defined

# %%
df['sepal.width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal.width, Length: 150, dtype: float64

# %%
dip=df['sepal.width']>3.5

# %%
dip
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: sepal.width, Length: 150, dtype: bool

# %%
 df['variety']=='iris-setosa'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: variety, Length: 150, dtype: bool

# %%
dip=(df['sepal.width']>3.5)& (df['variety']=='iris-setosa')

# %%
dip
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.rename(columns={'sepal.width':'Sepal_Width'})
# Out:
#      sepal.length  Sepal_Width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df['SepalArea']=df['sepal.length']*df['sepal.width']

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width', 'variety',
#        'SepalArea'],
#       dtype='object')

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      SepalArea
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ..         ...
# 145      20.10
# ...

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      SepalArea
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ..         ...
# 145      20.10
# ...

# %%
df['variety'].replace('iris-setosa','Setosa')
# Out:
# C:\Users\prasath.sundararajan\AppData\Local\Temp\ipykernel_19440\1054362912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['variety']=df['variety'].replace('iris-setosa','Setosa')

# %%
df['variety'].replace('iris-setosa','Setosa')
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 149, dtype: object

# %%
df.to_csv('cleaned_iris.csv',index=False)

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      SepalArea
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ..         ...
# 145      20.10
# ...

# %%
df.sort_values(by='sepal.width',ascending=True)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety  \
# 60            5.0          2.0           3.5          1.0  Versicolor
# 68            6.2          2.2           4.5          1.5  Versicolor
# 62            6.0          2.2           4.0          1.0  Versicolor
# 119           6.0          2.2           5.0          1.5   Virginica
# 87            6.3          2.3           4.4          1.3  Versicolor
# ..            ...          ...           ...          ...         ...
# 5             5.4          3.9           1.7          0.4      Setosa
# 14            5.8          4.0           1.2          0.2      Setosa
# 32            5.2          4.1           1.5          0.1      Setosa
# 33            5.5          4.2           1.4          0.2      Setosa
# 15            5.7          4.4           1.5          0.4      Setosa
#
#      SepalArea
# 60       10.00
# 68       13.64
# 62       13.20
# 119      13.20
# 87       14.49
# ..         ...
# ...

# %%
df.sort_values(by='sepal.width',ascending=False)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety  \
# 15            5.7          4.4           1.5          0.4      Setosa
# 33            5.5          4.2           1.4          0.2      Setosa
# 32            5.2          4.1           1.5          0.1      Setosa
# 14            5.8          4.0           1.2          0.2      Setosa
# 16            5.4          3.9           1.3          0.4      Setosa
# ..            ...          ...           ...          ...         ...
# 93            5.0          2.3           3.3          1.0  Versicolor
# 68            6.2          2.2           4.5          1.5  Versicolor
# 62            6.0          2.2           4.0          1.0  Versicolor
# 119           6.0          2.2           5.0          1.5   Virginica
# 60            5.0          2.0           3.5          1.0  Versicolor
#
#      SepalArea
# 15       25.08
# 33       23.10
# 32       21.32
# 14       23.20
# 16       21.06
# ..         ...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      SepalArea
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ..         ...
# 145      20.10
# ...

# %%
df.to_excel('numpy.ipynb',index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# ...

# %%
df.to_excel('Untitled.ipynb',index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2CC2-60AD
#
#  Directory of C:\Users\prasath.sundararajan\libraries
#
# 13-01-2025  17:43    <DIR>          .
# 13-01-2025  17:43    <DIR>          ..
# 13-01-2025  15:31    <DIR>          .ipynb_checkpoints
# 13-01-2025  17:32             5,557 cleaned_iris.csv
# 13-01-2025  15:30             3,975 iris.csv
# 13-01-2025  14:42             2,827 numpy.ipynb
# 13-01-2025  15:27            18,752 tips.csv
# 13-01-2025  17:43            80,721 Untitled.ipynb
#                5 File(s)        111,832 bytes
#                3 Dir(s)  10,600,525,824 bytes free

# %%
df.to_excel('tips.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# ...

# %%
df.to_excel('output.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_excel('output.xlsx',index=False)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('iris.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv('iris.csv')
#
# NameError: name 'pd' is not defined

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.to_excel('output.xlsx',index=False)

# %%
df.dropna()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df['sepal.width'].fillna(df['sepal.width'].mean())
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal.width, Length: 150, dtype: float64

# %%
df['variety'].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64
